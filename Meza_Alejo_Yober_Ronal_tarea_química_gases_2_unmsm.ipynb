# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# !pip install drawdata
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 17.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.9/121.9 kB 14.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.5/93.5 kB 9.0 MB/s eta 0:00:00
# ...

# %%
from drawdata import draw_scatter, draw_histogram, draw_line

# %%
draw_histogram()
# Out:
#         <iframe
#             width="800"
#             height="550"
#             src="https://drawdata.xyz/histogram.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df1 = pd.read_csv("data (6).csv")

# %%
df1
# Out:
#          x         y  z
# 0    0.000  0.085328  a
# 1    0.025  0.159328  a
# 2    0.050  0.327328  a
# 3    0.075  0.513328  a
# 4    0.100  0.595328  a
# ..     ...       ... ..
# 115  0.875  0.065328  c
# 116  0.900  0.051328  c
# 117  0.925  0.041328  c
# 118  0.950  0.033328  c
# 119  0.975  0.021328  c
#
# [120 rows x 3 columns]

# %%
plt.scatter(df1["x"],df1["y"])

# %%
df1["x"].mean()
# Out:
# 0.4875

# %%
df1["x"].median()
# Out:
# 0.4875

# %%
df1["x"].std()
# Out:
# 0.28979491444291217

# %%
df1.describe()
# Out:
#                 x           y
# count  120.000000  120.000000
# mean     0.487500    0.207968
# std      0.289795    0.227909
# min      0.000000   -0.004672
# 25%      0.243750    0.005496
# 50%      0.487500    0.136328
# 75%      0.731250    0.339328
# max      0.975000    0.955328

# %%
draw_histogram()
# Out:
#         <iframe
#             width="800"
#             height="550"
#             src="https://drawdata.xyz/histogram.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df2 = pd.read_csv("data (7).csv")

# %%
df2
# Out:
#          x         y  z
# 0    0.000  0.027556  a
# 1    0.025  0.075556  a
# 2    0.050  0.181556  a
# 3    0.075  0.279556  a
# 4    0.100  0.459556  a
# ..     ...       ... ..
# 115  0.875  0.149556  c
# 116  0.900  0.127556  c
# 117  0.925  0.107556  c
# 118  0.950  0.083556  c
# 119  0.975  0.057556  c
#
# [120 rows x 3 columns]

# %%
plt.scatter(df2["x"],df2["y"])

# %%
df2["x"].mean()
# Out:
# 0.4875

# %%
df2["x"].median()
# Out:
# 0.4875

# %%
df2["x"].std()
# Out:
# 0.28979491444291217

# %%
df2.describe()
# Out:
#                 x           y
# count  120.000000  120.000000
# mean     0.487500    0.230431
# std      0.289795    0.238608
# min      0.000000   -0.004444
# 25%      0.243750    0.027556
# 50%      0.487500    0.174556
# 75%      0.731250    0.340056
# max      0.975000    0.985556

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       120 non-null    float64
#  1   y       120 non-null    float64
#  2   z       120 non-null    object
# dtypes: float64(2), object(1)
# memory usage: 2.9+ KB

# %% [markdown]
#  compararlas para explicar la siguientes gráficas.

# %% [markdown]
# Al examinar el gráfico que relaciona la cantidad de moléculas con la velocidad molecular a una temperatura constante, los indicadores de tendencia central ofrecen datos acerca de la velocidad promedio del gas. Este análisis resulta valioso para comprender el comportamiento de las moléculas a nivel microscópico y cómo la temperatura constante influye en la distribución de las velocidades. Si los valores promedio y mediano son cercanos entre sí, podría sugerir una distribución simétrica de las velocidades.

# %% [markdown]
# Chang, R. (2015). Química (12ª edición). McGraw-Hill.
